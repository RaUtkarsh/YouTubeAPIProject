# %% [markdown]
# ## YouTube API Project EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('YouTubeAPIprojectDataset.csv')
df
# Out:
#       Unnamed: 0      videoId channelTitle  \
# 0              0  yor2MQwuOWw   theRadBrad
# 1              1  _94CM0rTQag   theRadBrad
# 2              2  MW_k0XuwUmA   theRadBrad
# 3              3  L4bYpQcxZXU   theRadBrad
# 4              4  EU4Turoatnk   theRadBrad
# ...          ...          ...          ...
# 7878        7878  cjeVjNPDuJk   theRadBrad
# 7879        7879  JkIcx6gjb3g   theRadBrad
# 7880        7880  KP4SXSJQXNY   theRadBrad
# 7881        7881  Ye9lTlCx7As   theRadBrad
# 7882        7882  2F8Hg1Jw6gY   theRadBrad
#
#                                                   title  \
# 0     THE CALLISTO PROTOCOL PS5 Walkthrough Gameplay...
# 1     THE CALLISTO PROTOCOL PS5 Walkthrough Gameplay...
# 2     GOTHAM KNIGHTS Walkthrough Gameplay Part 17 - ...
# 3     THE CALLISTO PROTOCOL PS5 Walkthrough Gameplay...
# 4     THE CALLISTO PROTOCOL PS5 Walkthrough Gameplay...
# ...                                                 ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7883 entries, 0 to 7882
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    7883 non-null   int64
#  1   videoId       7883 non-null   object
#  2   channelTitle  7883 non-null   object
#  3   title         7883 non-null   object
#  4   publishedAt   7883 non-null   object
#  5   tags          7881 non-null   object
#  6   description   7881 non-null   object
#  7   duration      7883 non-null   float64
#  8   caption       7883 non-null   bool
#  9   definition    7883 non-null   object
#  10  viewCount     7883 non-null   float64
#  11  likeCount     7880 non-null   float64
#  12  commentCount  7883 non-null   float64
#  13  publishedDay  7883 non-null   object
#  14  tagCount      7883 non-null   int64
# dtypes: bool(1), float64(4), int64(2), object(8)
# memory usage: 870.0+ KB

# %%
df['durationInMin'] = df['duration'].div(60)
df['durationInMin']
# Out:
# 0       26.300000
# 1       25.050000
# 2       33.150000
# 3       25.316667
# 4       24.033333
#           ...
# 7878     7.816667
# 7879     3.833333
# 7880     5.500000
# 7881     2.216667
# 7882     8.833333
# Name: durationInMin, Length: 7883, dtype: float64

# %%
df = df.drop('Unnamed: 0', axis = 1)

# %%
df.isna().sum()
# Out:
# videoId          0
# channelTitle     0
# title            0
# publishedAt      0
# tags             2
# description      2
# duration         0
# caption          0
# definition       0
# viewCount        0
# likeCount        3
# commentCount     0
# publishedDay     0
# tagCount         0
# durationInMin    0
# dtype: int64

# %%
df.describe()
# Out:
#           duration     viewCount      likeCount  commentCount     tagCount  \
# count  7883.000000  7.883000e+03    7880.000000   7883.000000  7883.000000
# mean   1305.630471  7.500081e+05   16094.885406   1486.849930    20.528606
# std     726.673441  1.144628e+06   21956.398236   3241.483234     6.736931
# min       0.000000  0.000000e+00       5.000000      0.000000     0.000000
# 25%     815.500000  2.338615e+05    5291.750000    452.000000    16.000000
# 50%    1149.000000  4.437860e+05   10618.500000    774.000000    18.000000
# 75%    1578.000000  8.362765e+05   18512.750000   1343.000000    24.000000
# max    6971.000000  2.326318e+07  371287.000000  83905.000000    60.000000
#
#        durationInMin
# count    7883.000000
# mean       21.760508
# std        12.111224
# min         0.000000
# 25%        13.591667
# 50%        19.150000
# 75%        26.300000
# max       116.183333

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize = (15, 13))

# Create the first boxplot in the first row and first column
sns.boxplot(data=df, y='duration', ax=ax[0][0])

# Create the second boxplot in the first row and second column
sns.boxplot(data=df, y='viewCount', ax=ax[0][1])

# Create the third boxplot in the second row and first column
sns.boxplot(data=df, y='likeCount', ax=ax[1][0])

# Create the fourth boxplot in the second row and second column
sns.boxplot(data=df, y='commentCount', ax=ax[1][1])

# Show the plot
plt.show()

# %%
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['figure.facecolor'] = 'white'

df_new = df.copy()
df_new = df_new.sort_values('viewCount', ascending=False)
df_new = df_new.head(5)

sns.barplot(data = df_new, x = 'title', y = 'viewCount')

plt.title('Most Viewed Videos')
plt.xlabel("Video Title")
plt.ylabel("Views")
plt.xticks(rotation = 90)
plt.show()

del df_new

# %%
df_copy = df.copy()
df_copy = df_copy.sort_values('likeCount', ascending = False)
df_copy = df_copy.head(5)

sns.barplot(data = df_copy, x = 'title', y = 'likeCount')
plt.title('Most Liked Videos')
plt.xlabel('Video Title')
plt.ylabel('Likes')
plt.xticks(rotation = 90)

plt.show()

# %%
cnt_videos = df.groupby('publishedDay').size().sort_values(ascending = False)
plt.bar(cnt_videos.index, cnt_videos.values)
plt.title('Number of videos uploaded on each day of the week')
plt.xticks(cnt_videos.index)
plt.show()
